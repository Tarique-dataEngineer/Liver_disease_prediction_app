# %% [markdown]
# #Indian Liver Disease Classification Machine Learning

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ##Data Analysis

# %%
data=pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')

# %%
data.head()
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65  Female            0.7               0.1           187       16
# 1   62    Male           10.9               5.5           699       64
# 2   62    Male            7.3               4.1           490       60
# 3   58    Male            1.0               0.4           182       14
# 4   72    Male            3.9               2.0           195       27
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1
# 2        68   7.0   3.3     0.89           1
# 3        20   6.8   3.4     1.00           1
# 4        59   7.3   2.4     0.40           1

# %%
data.tail()
# Out:
#      age gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 578   60   Male            0.5               0.1           500       20
# 579   40   Male            0.6               0.1            98       35
# 580   52   Male            0.8               0.2           245       48
# 581   31   Male            1.3               0.5           184       29
# 582   38   Male            1.0               0.3           216       21
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# 578        34   5.9   1.6     0.37           2
# 579        31   6.0   3.2     1.10           1
# 580        49   6.4   3.2     1.00           1
# 581        32   6.8   3.4     1.00           1
# 582        24   7.3   4.4     1.50           2

# %%
#Looking at the information contained within the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               583 non-null    int64
#  1   gender            583 non-null    object
#  2   tot_bilirubin     583 non-null    float64
#  3   direct_bilirubin  583 non-null    float64
#  4   tot_proteins      583 non-null    int64
#  5   albumin           583 non-null    int64
#  6   ag_ratio          583 non-null    int64
#  7   sgpt              583 non-null    float64
#  8   sgot              583 non-null    float64
#  9   alkphos           579 non-null    float64
#  10  is_patient        583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
data.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %% [markdown]
# ###Imputation using SkLearns Simple Imputer for Missing Values

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
#Imputing values
data['alkphos']=imp.fit_transform(data[['alkphos']])

# %%
data.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             0
# is_patient          0
# dtype: int64

# %%
data.describe()
# Out:
#               age  tot_bilirubin  direct_bilirubin  tot_proteins      albumin  \
# count  583.000000     583.000000        583.000000    583.000000   583.000000
# mean    44.746141       3.298799          1.486106    290.576329    80.713551
# std     16.189833       6.209522          2.808498    242.937989   182.620356
# min      4.000000       0.400000          0.100000     63.000000    10.000000
# 25%     33.000000       0.800000          0.200000    175.500000    23.000000
# 50%     45.000000       1.000000          0.300000    208.000000    35.000000
# 75%     58.000000       2.600000          1.300000    298.000000    60.500000
# max     90.000000      75.000000         19.700000   2110.000000  2000.000000
#
#           ag_ratio        sgpt        sgot     alkphos  is_patient
# count   583.000000  583.000000  583.000000  583.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.947064    1.286449
# std     288.918529    1.085451    0.795519    0.318492    0.452490
# min      10.000000    2.700000    0.900000    0.300000    1.000000
# 25%      25.000000    5.800000    2.600000    0.700000    1.000000
# 50%      42.000000    6.600000    3.100000    0.947064    1.000000
# 75%      87.000000    7.200000    3.800000    1.100000    2.000000
# max    4929.000000    9.600000    5.500000    2.800000    2.000000

# %% [markdown]
# Age has been excluded as it is a String Value and not a Number

# %%
#Replacing Male and Female with 1 and 0
data['gender'] = data['gender'].apply(lambda x:1 if x == 'Male' else 0)

# %%
#Now looking at the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               583 non-null    int64
#  1   gender            583 non-null    int64
#  2   tot_bilirubin     583 non-null    float64
#  3   direct_bilirubin  583 non-null    float64
#  4   tot_proteins      583 non-null    int64
#  5   albumin           583 non-null    int64
#  6   ag_ratio          583 non-null    int64
#  7   sgpt              583 non-null    float64
#  8   sgot              583 non-null    float64
#  9   alkphos           583 non-null    float64
#  10  is_patient        583 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 50.2 KB

# %%
data.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             0
# is_patient          0
# dtype: int64

# %% [markdown]
# ###Correlation Plot Map

# %%
#Now it's time to see the correlation
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8f075_row0_col0, #T_8f075_row1_col1, #T_8f075_row2_col2, #T_8f075_row3_col3, #T_8f075_row4_col4, #T_8f075_row5_col5, #T_8f075_row6_col6, #T_8f075_row7_col7, #T_8f075_row8_col8, #T_8f075_row9_col9, #T_8f075_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col1, #T_8f075_row9_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col2, #T_8f075_row6_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col4, #T_8f075_row1_col0, #T_8f075_row1_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_8f075_row0_col5, #T_8f075_row5_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col6, #T_8f075_row8_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col7, #T_8f075_row0_col8, #T_8f075_row3_col10, #T_8f075_row4_col9, #T_8f075_row8_col0, #T_8f075_row8_col1, #T_8f075_row8_col2, #T_8f075_row9_col4, #T_8f075_row10_col2, #T_8f075_row10_col3, #T_8f075_row10_col5, #T_8f075_row10_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col9, #T_8f075_row8_col3, #T_8f075_row9_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8f075_row0_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8f075_row1_col4, #T_8f075_row2_col1, #T_8f075_row7_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col7, #T_8f075_row9_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col8, #T_8f075_row4_col7, #T_8f075_row6_col7, #T_8f075_row6_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col9, #T_8f075_row5_col8, #T_8f075_row10_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8f075_row1_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_8f075_row2_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_8f075_row2_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_8f075_row2_col4, #T_8f075_row3_col6, #T_8f075_row5_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_8f075_row2_col5, #T_8f075_row6_col4, #T_8f075_row8_col10, #T_8f075_row9_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_8f075_row2_col6, #T_8f075_row10_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_8f075_row2_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_8f075_row2_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8f075_row2_col9, #T_8f075_row2_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8f075_row3_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_8f075_row3_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8f075_row3_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_8f075_row3_col4, #T_8f075_row7_col9 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_8f075_row3_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8f075_row3_col7, #T_8f075_row6_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_8f075_row3_col8, #T_8f075_row3_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_8f075_row4_col0, #T_8f075_row4_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_8f075_row4_col1, #T_8f075_row7_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8f075_row4_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_8f075_row4_col3, #T_8f075_row5_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_8f075_row4_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_8f075_row4_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_8f075_row4_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_8f075_row5_col0, #T_8f075_row6_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_8f075_row5_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_8f075_row5_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_8f075_row5_col6, #T_8f075_row8_col7 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_8f075_row5_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_8f075_row5_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8f075_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8f075_row6_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_8f075_row6_col5 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_8f075_row6_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col5, #T_8f075_row10_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col8 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_8f075_row7_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8f075_row8_col4, #T_8f075_row8_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_8f075_row8_col9 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_8f075_row9_col0, #T_8f075_row10_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8f075_row9_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_8f075_row9_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_8f075_row9_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_8f075_row9_col8 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_8f075_row10_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8f075_row10_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# </style>
# <table id="T_8f075" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f075_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_8f075_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_8f075_level0_col2" class="col_heading level0 col2" >tot_bilirubin</th>
#       <th id="T_8f075_level0_col3" class="col_heading level0 col3" >direct_bilirubin</th>
#       <th id="T_8f075_level0_col4" class="col_heading level0 col4" >tot_proteins</th>
#       <th id="T_8f075_level0_col5" class="col_heading level0 col5" >albumin</th>
#       <th id="T_8f075_level0_col6" class="col_heading level0 col6" >ag_ratio</th>
#       <th id="T_8f075_level0_col7" class="col_heading level0 col7" >sgpt</th>
#       <th id="T_8f075_level0_col8" class="col_heading level0 col8" >sgot</th>
#       <th id="T_8f075_level0_col9" class="col_heading level0 col9" >alkphos</th>
#       <th id="T_8f075_level0_col10" class="col_heading level0 col10" >is_patient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f075_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_8f075_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8f075_row0_col1" class="data row0 col1" >0.056560</td>
#       <td id="T_8f075_row0_col2" class="data row0 col2" >0.011763</td>
#       <td id="T_8f075_row0_col3" class="data row0 col3" >0.007529</td>
#       <td id="T_8f075_row0_col4" class="data row0 col4" >0.080425</td>
#       <td id="T_8f075_row0_col5" class="data row0 col5" >-0.086883</td>
#       <td id="T_8f075_row0_col6" class="data row0 col6" >-0.019910</td>
#       <td id="T_8f075_row0_col7" class="data row0 col7" >-0.187461</td>
#       <td id="T_8f075_row0_col8" class="data row0 col8" >-0.265924</td>
#       <td id="T_8f075_row0_col9" class="data row0 col9" >-0.216089</td>
#       <td id="T_8f075_row0_col10" class="data row0 col10" >-0.137351</td>
#     </tr>
#     <tr>
#       <th id="T_8f075_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_8f075_row1_col0" class="data row1 col0" >0.056560</td>
#       <td id="T_8f075_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8f075_row1_col2" class="data row1 col2" >0.089291</td>

# %% [markdown]
# ###Seaborns PairPlot

# %%
import seaborn as sns
#Implementing Pairplot to see the various mixtures
sns.set()
sns.pairplot(data, hue= 'is_patient', kind = 'reg')

# %% [markdown]
# ###Variance Inflation to see the best models

# %% [markdown]
# Later on, in the notebook, there will be a chance to see the best features by using Random Forests best features method

# %%
#Importing variance inflation factor from statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
data.head()
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65       0            0.7               0.1           187       16
# 1   62       1           10.9               5.5           699       64
# 2   62       1            7.3               4.1           490       60
# 3   58       1            1.0               0.4           182       14
# 4   72       1            3.9               2.0           195       27
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1
# 2        68   7.0   3.3     0.89           1
# 3        20   6.8   3.4     1.00           1
# 4        59   7.3   2.4     0.40           1

# %% [markdown]
# ###Making the Test Set, excluding the Target, i.e "y" variable in order to meet up with Variance Inflations (vif's) syntax

# %%
#Making New Data Sets for Computation
#Select all rows except for the Target variable
Test_Set_Var = data.iloc[:,:10]

# %%
df = pd.DataFrame()
df["vif_index"] = [vif(Test_Set_Var.values, i) for i in range(Test_Set_Var.shape[1])]
df["features"] = Test_Set_Var.columns
df.sort_values(by = 'vif_index', ascending=False)
# Out:
#     vif_index          features
# 8  133.055715              sgot
# 7  101.860900              sgpt
# 9   25.717649           alkphos
# 0    7.813077               age
# 3    5.736207  direct_bilirubin
# 2    5.479228     tot_bilirubin
# 1    4.087526            gender
# 5    3.308649           albumin
# 6    3.192721          ag_ratio
# 4    2.650280      tot_proteins

# %%
#Over here we can see that sgot, sgpt, and alkphos have the highest amount for the VIF Index.
#Normally, a value above 10 would mean that we should slash it out however,
#This is a medical data set, we should still consider these variables as it seems to have some
#form of correlation according to my minimal industry knowledge. Any input would be appreciated!

# %% [markdown]
# ###Seeing Variations in outputs with respect to Gender

# %% [markdown]
# The plots are quite small hence, I've decided to plot certain plots individually and print out a few Data Frames

# %%
gender_data = data[['gender', 'is_patient']].groupby('gender', as_index = False).agg(np.sum)
gender_data
# Out:
#    gender  is_patient
# 0       0         192
# 1       1         558

# %%
#Importing MatplotLib
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (12,8))
plt.title('Men and Womnens Ratio with respect to Having Disease or Not')
sns.barplot(x = 'gender', y = 'is_patient', data = data)
# Out:
# <Axes: title={'center': 'Men and Womnens Ratio with respect to Having Disease or Not'}, xlabel='gender', ylabel='is_patient'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (12,8))
plt.title('Men and Womnens Numbers with respect to Having Disease or Not')
sns.barplot(x = 'gender', y = 'is_patient', data = gender_data)
# Out:
# <Axes: title={'center': 'Men and Womnens Numbers with respect to Having Disease or Not'}, xlabel='gender', ylabel='is_patient'>

# %% [markdown]
# ###We can see that Men have a higher chance of having Liver Disease, but how/why ?

# %% [markdown]
# Trying to see a relationship between Proteins and Gender. I'm not a Bio-med Major,
#
# We can see a relationship between total_proteins, gender and their final outcome

# %%
df_liver_TP = data[['gender', 'tot_proteins', 'is_patient']].groupby(['gender'], as_index=False).agg(np.sum)
df_liver_TP
# Out:
#    gender  tot_proteins  is_patient
# 0       0         42932         192
# 1       1        126474         558

# %%
#Plotting it on a graph for better visualization
plt.figure(figsize = (12,8))
sns.barplot(x = 'gender', y = 'tot_proteins', hue= 'is_patient', data = df_liver_TP)
# Out:
# <Axes: xlabel='gender', ylabel='tot_proteins'>

# %%
#Before moving forward we can try and see the different stats of the whole data set
#This is without the NaN's meaning we haven't includes the empty variables
data.describe()
# Out:
#               age      gender  tot_bilirubin  direct_bilirubin  tot_proteins  \
# count  583.000000  583.000000     583.000000        583.000000    583.000000
# mean    44.746141    0.756432       3.298799          1.486106    290.576329
# std     16.189833    0.429603       6.209522          2.808498    242.937989
# min      4.000000    0.000000       0.400000          0.100000     63.000000
# 25%     33.000000    1.000000       0.800000          0.200000    175.500000
# 50%     45.000000    1.000000       1.000000          0.300000    208.000000
# 75%     58.000000    1.000000       2.600000          1.300000    298.000000
# max     90.000000    1.000000      75.000000         19.700000   2110.000000
#
#            albumin     ag_ratio        sgpt        sgot     alkphos  \
# count   583.000000   583.000000  583.000000  583.000000  583.000000
# mean     80.713551   109.910806    6.483190    3.141852    0.947064
# std     182.620356   288.918529    1.085451    0.795519    0.318492
# min      10.000000    10.000000    2.700000    0.900000    0.300000
# 25%      23.000000    25.000000    5.800000    2.600000    0.700000
# 50%      35.000000    42.000000    6.600000    3.100000    0.947064
# 75%      60.500000    87.000000    7.200000    3.800000    1.100000
# max    2000.000000  4929.000000    9.600000    5.500000    2.800000
#
#        is_patient
# count  583.000000
# mean     1.286449
# std      0.452490
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
data.shape
# Out:
# (583, 11)

# %% [markdown]
# ##Model Machine Learning Section

# %%
#Importing the Necessary Modules
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score

# %%
#Defining X and y as we never defined it
X = data.iloc[:, :10]
y = data['is_patient']

# %%
#Using Scaling Methods to scale the entire data set as I'm running into errors
scaler=MinMaxScaler()
scaled_values=scaler.fit_transform(X)
X.loc[:,:]=scaled_values
# Out:
# <ipython-input-34-5245e6a254a5>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X.loc[:,:]=scaled_values

# %% [markdown]
# ###Scaling using MinMaxScaler

# %% [markdown]
# Using Hold Out Method.

# %%
#I was a bit skeptical to use the Cross-Validation method but I would maybe give it a try

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.3, random_state = 123)

# %%
#Checking to see isnull again, I'm good so far :)
print(X_train.isnull().sum())
print(y_train.isnull().sum())
print(X_test.isnull().sum())
print(y_test.isnull().sum())
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             0
# dtype: int64
# 0
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             0
# dtype: int64
# 0

# %%
print(f'Shape of X:{X_train.shape}, Shape of y: {y_train.shape}')
# Out:
# Shape of X:(408, 10), Shape of y: (408,)

# %%
print(f'Shape of X:{X_test.shape}, Shape of y: {y_test.shape}')
# Out:
# Shape of X:(175, 10), Shape of y: (175,)

# %% [markdown]
# ##Instantiating Classifiers

# %%
#Instantiating 3 Classification Models
dt = DecisionTreeClassifier(max_depth=4,min_samples_leaf=0.14,random_state=1)
lr = LogisticRegression(solver='lbfgs', multi_class='ovr')
KNN_1 = KNN(n_neighbors = 10)
rf = RandomForestClassifier(n_estimators=25, random_state=2)

# %% [markdown]
# Making a List of Tuples for Automating the results
# First
#
# I would like to individually hard code them however, both methods shall be used :)

# %%
classifiers = [('Decision Tree',dt),('Logistic Regression',lr),('KNN',KNN_1), ('Random Forest', rf)]

# %% [markdown]
# ##Decision Tree Classifier

# %%
dt.fit(X_train, y_train)
dt_y_pred = dt.predict(X_test)
dt_acc_test = accuracy_score(y_test, dt_y_pred)
print('Test set accuracy of dt: {:.2f}'.format(dt_acc_test))
# Out:
# Test set accuracy of dt: 0.70

# %% [markdown]
# ##Logisitic Regression

# %%
#Logistic Regression Accuracy
lr.fit(X_train, y_train)
lr_y_pred = lr.predict(X_test)
lr_acc_test = accuracy_score(y_test, lr_y_pred)
print('Test set accuracy of dt: {:.2f}'.format(lr_acc_test))
# Out:
# Test set accuracy of dt: 0.73

# %% [markdown]
# ##K-Neighbors Classifier

# %%
#KNN Accuracy
KNN_1.fit(X_train, y_train)
knn_y_pred = KNN_1.predict(X_test)
knn_acc_test = accuracy_score(y_test, knn_y_pred)
print('Test set accuracy of dt: {:.2f}'.format(knn_acc_test))
# Out:
# Test set accuracy of dt: 0.69

# %% [markdown]
# ##Random Forest Classifier

# %%
#Random Forest Accuracy
rf.fit(X_train, y_train)
rf_y_pred = rf.predict(X_test)
rf_acc_test = accuracy_score(y_test, rf_y_pred)
print('Test set accuracy of dt: {:.2f}'.format(rf_acc_test))
# Out:
# Test set accuracy of dt: 0.73

# %% [markdown]
# ##Random Forest's Feature Importance

# %%
#Using RF to see Best Features
# Create a pd.Series of features importances
importances = pd.Series(data=rf.feature_importances_,
                        index= X_train.columns)

# Sort importances
importances_sorted = importances.sort_values()

# Draw a horizontal barplot of importances_sorted
importances_sorted.plot(kind='barh', color='lightgreen')
plt.title('Features Importances')
plt.show()

# %%
#Decided to run them all together and print them out in a for loop for Automation
for clf_name, clf in classifiers:
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    print('{:s} : {:.3f}'.format(clf_name, accuracy_score(y_test, y_pred)))
# Out:
# Decision Tree : 0.703
# Logistic Regression : 0.726
# KNN : 0.691
# Random Forest : 0.731

# %% [markdown]
# **Predict Proba Scores**
#
# For those who don't know, Predict Proba basically means the probability of having the correct output i.e 1 or 0

# %%
#Predict Proba Scores
y_score1 = dt.predict_proba(X_test)[:,1]
y_score2 = lr.predict_proba(X_test)[:,1]
y_score3 = KNN_1.predict_proba(X_test)[:,1]
y_score4 = rf.predict_proba(X_test)[:,1]

# %% [markdown]
# ##Receiver Operating Characteristic (ROC) and Area under the curve (AUC) Score

# %%
print('roc_auc_score for DecisionTree: ', roc_auc_score(y_test, y_score1))
print('roc_auc_score for Logistic Regression: ', roc_auc_score(y_test, y_score2))
print('roc_auc_score for KNearest Neighbors: ', roc_auc_score(y_test, y_score3))
print('roc_auc_score for Random Forest: ', roc_auc_score(y_test, y_score4))
# Out:
# roc_auc_score for DecisionTree:  0.7021379980563655
# roc_auc_score for Logistic Regression:  0.7048914804016846
# roc_auc_score for KNearest Neighbors:  0.6484450923226434
# roc_auc_score for Random Forest:  0.7364755425979915

# %%
#Plotting the Random Forests ROC Curve

# %%
#define metrics
y_pred_proba_rf_auc = rf.predict_proba(X_test)[::,1]
fpr_rf, tpr_rf, _ = roc_curve(y_test,  y_pred_proba_rf_auc, pos_label = 2)
rf_auc = roc_auc_score(y_test, y_score4)


#create ROC curve
plt.plot(fpr_rf,tpr_rf,label="AUC="+str(rf_auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ###Plotting the Logistic Regressions ROC Curve

# %%
#define metrics
y_pred_proba_auc_lr = lr.predict_proba(X_test)[::,1]
fpr_lr, tpr_lr, _ = roc_curve(y_test,  y_pred_proba_auc_lr, pos_label = 2)
lr_auc = roc_auc_score(y_test, y_score2)


#create ROC curve
plt.plot(fpr_lr,tpr_lr,label="AUC="+str(lr_auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc =4)
plt.show()

# %% [markdown]
# ###Plotting the KNearestNeighbors ROC Curve

# %%
#define metrics
y_pred_proba_auc_knn = KNN_1.predict_proba(X_test)[::,1]
fpr_knn, tpr_knn, _ = roc_curve(y_test,  y_pred_proba_auc_knn, pos_label = 2)
knn_auc = roc_auc_score(y_test, y_score3)

#create ROC curve
plt.plot(fpr_knn,tpr_knn,label="AUC="+str(knn_auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc =4)
plt.show()

# %% [markdown]
# ###Plotting the Decision Tree's ROC Curve

# %%
#define metrics
y_pred_proba_auc_dt = dt.predict_proba(X_test)[::,1]
fpr_dt, tpr_dt, _ = roc_curve(y_test,  y_pred_proba_auc_dt, pos_label = 2)
dt_auc = roc_auc_score(y_test, y_score1)


#create ROC curve
plt.plot(fpr_dt,tpr_dt,label="AUC="+str(dt_auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc =4)
plt.show()

# %%
#Results in a Data Frame

# %%
results = pd.DataFrame({'Model': ['Decision Tree','Logistic Regression', 'KNN','Random Forest Classifier'],
                        'Roc_Score': [roc_auc_score(y_test, y_score1), roc_auc_score(y_test, y_score2),roc_auc_score(y_test, y_score3), roc_auc_score(y_test, y_score4)],
                       'Accuracy_Score': [dt_acc_test, lr_acc_test,knn_acc_test, rf_acc_test]})
df_results = results.sort_values(by='Roc_Score', ascending=False)
df_results
# Out:
#                       Model  Roc_Score  Accuracy_Score
# 3  Random Forest Classifier   0.736476        0.731429
# 1       Logistic Regression   0.704891        0.725714
# 0             Decision Tree   0.702138        0.702857
# 2                       KNN   0.648445        0.691429

# %%
import pickle

# Assuming rf is your Random Forest model

# Fit the model
rf.fit(X_train, y_train)

# Predict on the test set
rf_y_pred = rf.predict(X_test)

# Calculate accuracy
rf_acc_test = accuracy_score(y_test, rf_y_pred)
print('Test set accuracy of Random Forest: {:.2f}'.format(rf_acc_test))

# Save the model
with open('model.pkl', 'wb') as file:
    pickle.dump(rf, file)
# Out:
# Test set accuracy of Random Forest: 0.73
